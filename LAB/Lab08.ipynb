# %%
#Exercise 1
Andersen = {"The Emperor’s New Clothes", "The Little Mermaid", "The Little Match Girl", "The Snow Queen"}
print("Andersen:", Andersen)
# Out:
# Andersen: {'The Emperor’s New Clothes', 'The Little Match Girl', 'The Little Mermaid', 'The Snow Queen'}

# %%
#Exercise 2
Shakespeare = {"Romeo and Juliet", "Hamlet", "King Lear", "Macbeth", "A Midsummer Night’s Dream", "A Comedy of Errors"}
print("Shakespeare:", Shakespeare)
# Out:
# Shakespeare: {'A Comedy of Errors', 'King Lear', 'Romeo and Juliet', 'Hamlet', 'A Midsummer Night’s Dream', 'Macbeth'}

# %%
#Exercise 3
Tragedy = {"Medea", "Octavia", "Oedipus", "Ur-Hamlet"}
Comedy = {"The Three Musketeer", "The Clouds"}
Uncategory = {"Don Quixote", "Rapunzel", "Cinderella"}
print("Tragedy:", Tragedy)
print("Comedy:", Comedy)
print("Uncategory:", Uncategory)
# Out:
# Tragedy: {'Ur-Hamlet', 'Medea', 'Oedipus', 'Octavia'}
# Comedy: {'The Three Musketeer', 'The Clouds'}
# Uncategory: {'Rapunzel', 'Don Quixote', 'Cinderella'}

# %%
#Exercise 4
Shakespeare_Tragedy = Shakespeare.difference(Tragedy)
print("Shakespeare_Tragedy:", Shakespeare_Tragedy)
# Out:
# Shakespeare_Tragedy: {'King Lear', 'A Comedy of Errors', 'Romeo and Juliet', 'A Midsummer Night’s Dream', 'Macbeth', 'Hamlet'}

# %%
#Exercise 5
Andersen_Comedy = Andersen.difference(Comedy)
print("Andersen_Comedy:", Andersen_Comedy)
# Out:
# Andersen_Comedy: {'The Emperor’s New Clothes', 'The Little Match Girl', 'The Little Mermaid', 'The Snow Queen'}

# %%
#Exercise 6
relations = {
    "Andersen_Comedy": {
        "Shakespeare": Andersen_Comedy.issubset(Shakespeare),
        "Andersen": Andersen_Comedy.issubset(Andersen),
        "Tragedy": Andersen_Comedy.isdisjoint(Tragedy),
        "Comedy": Andersen_Comedy.isdisjoint(Comedy),
        "Uncategory": Andersen_Comedy.isdisjoint(Uncategory),
    },
    "Shakespeare_Tragedy": {
        "Shakespeare": Shakespeare_Tragedy.issubset(Shakespeare),
        "Andersen": Shakespeare_Tragedy.issubset(Andersen),
        "Tragedy": Shakespeare_Tragedy.issubset(Tragedy),
        "Comedy": Shakespeare_Tragedy.isdisjoint(Comedy),
        "Uncategory": Shakespeare_Tragedy.isdisjoint(Uncategory),
    }
}

print("Relations:")
for set_name, set_relations in relations.items():
    print(set_name)
    for relation, value in set_relations.items():
        print(f"  {relation}: {value}")
# Out:
# Relations:
# Andersen_Comedy
#   Shakespeare: False
#   Andersen: True
#   Tragedy: True
#   Comedy: True
#   Uncategory: True
# Shakespeare_Tragedy
#   Shakespeare: True
#   Andersen: False
#   Tragedy: False
#   Comedy: True
#   Uncategory: True

# %%
#Exercise 7
Work = Andersen.union(Shakespeare, Tragedy, Comedy, Uncategory)
print("Work:", Work)
# Out:
# Work: {'Octavia', 'King Lear', 'The Emperor’s New Clothes', 'A Comedy of Errors', 'Romeo and Juliet', 'The Three Musketeer', 'Macbeth', 'Don Quixote', 'The Snow Queen', 'The Little Match Girl', 'Oedipus', 'Rapunzel', 'A Midsummer Night’s Dream', 'Cinderella', 'Ur-Hamlet', 'The Little Mermaid', 'The Clouds', 'Hamlet', 'Medea'}

# %%
#Exercise 8
Author = {"Hans Christian Andersen", "Shakespeare", "Unknown"}
print("Author:", Author)
# Out:
# Author: {'Hans Christian Andersen', 'Unknown', 'Shakespeare'}

# %%
#Exercise 9
Author_Of = {
    "The Emperor’s New Clothes": "Hans Christian Andersen",
    "The Little Mermaid": "Hans Christian Andersen",
    "The Little Match Girl": "Hans Christian Andersen",
    "The Snow Queen": "Hans Christian Andersen",
    "Romeo and Juliet": "Shakespeare",
    "Hamlet": "Shakespeare",
    "King Lear": "Shakespeare",
    "Macbeth": "Shakespeare",
    "A Midsummer Night’s Dream": "Shakespeare",
    "A Comedy of Errors": "Shakespeare",
    "Medea": "Unknown",
    "Octavia": "Unknown",
    "Oedipus": "Unknown",
    "Ur-Hamlet": "Unknown",
    "The Three Musketeer": "Unknown",
    "The Clouds": "Unknown",
    "Don Quixote": "Unknown",
    "Rapunzel": "Unknown",
    "Cinderella": "Unknown",
}

print("Author_Of:", Author_Of)
# Out:
# Author_Of: {'The Emperor’s New Clothes': 'Hans Christian Andersen', 'The Little Mermaid': 'Hans Christian Andersen', 'The Little Match Girl': 'Hans Christian Andersen', 'The Snow Queen': 'Hans Christian Andersen', 'Romeo and Juliet': 'Shakespeare', 'Hamlet': 'Shakespeare', 'King Lear': 'Shakespeare', 'Macbeth': 'Shakespeare', 'A Midsummer Night’s Dream': 'Shakespeare', 'A Comedy of Errors': 'Shakespeare', 'Medea': 'Unknown', 'Octavia': 'Unknown', 'Oedipus': 'Unknown', 'Ur-Hamlet': 'Unknown', 'The Three Musketeer': 'Unknown', 'The Clouds': 'Unknown', 'Don Quixote': 'Unknown', 'Rapunzel': 'Unknown', 'Cinderella': 'Unknown'}

# %%
#Exercise 10
Written_By = {v: k for k, v in Author_Of.items()}
print("Written_By:", Written_By)
# Out:
# Written_By: {'Hans Christian Andersen': 'The Snow Queen', 'Shakespeare': 'A Comedy of Errors', 'Unknown': 'Cinderella'}

# %%
#Exercise 11
Work_Count = {}
for work in Work:
    count = sum(work in s for s in [Andersen, Shakespeare, Tragedy, Comedy, Uncategory])
    Work_Count[work] = count
print("Work_Count:", Work_Count)
# Out:
# Work_Count: {'Octavia': 1, 'King Lear': 1, 'The Emperor’s New Clothes': 1, 'A Comedy of Errors': 1, 'Romeo and Juliet': 1, 'The Three Musketeer': 1, 'Macbeth': 1, 'Don Quixote': 1, 'The Snow Queen': 1, 'The Little Match Girl': 1, 'Oedipus': 1, 'Rapunzel': 1, 'A Midsummer Night’s Dream': 1, 'Cinderella': 1, 'Ur-Hamlet': 1, 'The Little Mermaid': 1, 'The Clouds': 1, 'Hamlet': 1, 'Medea': 1}

# %%
#Exercise 12
exercise_text = "Within the content of Exercise section count how many words are in this section of the Lab."
exercise_word_count = len(exercise_text.split())
print("Word count in the Exercise section:", exercise_word_count)
# Out:
# Word count in the Exercise section: 17

# %%
#Exercise 13
word_count = {}
for word in exercise_text.split():
    word_count[word] = word_count.get(word, 0) + 1

sorted_word_count = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
print("Word count occurrencesHere's the Python code that addresses the requirements outlined: ", sorted_word_count)
# Out:
# Word count occurrencesHere's the Python code that addresses the requirements outlined:  [('the', 2), ('of', 2), ('section', 2), ('Within', 1), ('content', 1), ('Exercise', 1), ('count', 1), ('how', 1), ('many', 1), ('words', 1), ('are', 1), ('in', 1), ('this', 1), ('Lab.', 1)]
